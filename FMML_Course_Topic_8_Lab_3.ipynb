# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarunn06/Fmml_Project_labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-28 10:58:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  83.5MB/s    in 0.8s
#
# 2023-05-28 10:58:04 (83.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 28713  1707.05740v5  Human action recognition in 3D skeleton sequen...    cs
# 1861   1711.08870v1  This paper proposes the continuous semantic to...  stat
# 11351  1510.08628v2  Developing efficient and scalable algorithms f...  stat
# 3312   1506.02565v4  We propose a Bayesian evidence framework to fa...    cs
# 3900   cs/0305020v1  In an earlier article [J. Schubert, On nonspec...    cs
# ...             ...                                                ...   ...
# 12592  1803.03666v1  We propose a Standing Wave Decomposition (SWD)...  stat
# 39450  1605.03483v3  In robotic surgery, tool tracking is important...    cs
# 22346  1603.00389v2  We consider Bayesian optimization of an expens...  stat
# 30303  1711.10796v1  Despite recent success on 2D human pose estima...    cs
# 6503   1702.08536v3  Threshold tests have recently been proposed as...  stat
#
#                                                    title  year  \
# 28713  Skeleton-Based Human Action Recognition with G...  2017
# 1861   Continuous Semantic Topic Embedding Model Usin...  2017
# 11351  WarpLDA: a Cache Efficient O(1) Algorithm for ...  2015
# 3312   Learning to Select Pre-Trained Deep Representa...  2015
# 3900                     Specifying nonspecific evidence  2003
# ...                                                  ...   ...
# 12592       Standing Wave Decomposition Gaussian Process  2018
# 39450  Real-time 3D Tracking of Articulated Tools for...  2016
# 22346              Multi-Information Source Optimization  2016
# 30303  DeepSkeleton: Skeleton Map for 3D Human Pose R...  2017
# 6503   Fast Threshold Tests for Detecting Discrimination  2017
#
#                                                 keywords
# 28713  [recognition, sequences, attracted, attention,...
# 1861   [continuous, embedding, variables, documents, ...
# 11351  [developing, efficient, algorithms, dirichlet,...
# 3312   [framework, facilitate, convolutional, framewo...
# 3900   [nonspecific, established, criterion, metaconf...
# ...                                                  ...
# 12592  [decomposition, approximation, regression, inv...
# 39450  [important, providing, interaction, facilitati...
# 22346  [optimization, expensive, objective, approxima...
# 30303  [estimation, estimation, challenge, ambiguity,...
# 6503   [threshold, detecting, decisions, extensions, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 28713    [recognition, sequences, attracted, attention,...
# 1861     [continuous, embedding, variables, documents, ...
# 11351    [developing, efficient, algorithms, dirichlet,...
# 3312     [framework, facilitate, convolutional, framewo...
# 3900     [nonspecific, established, criterion, metaconf...
#                                ...
# 21135    [knowledge, incomplete, knowledge, repositorie...
# 6229     [classifier, classification, minimizes, classi...
# 7271     [interpretability, applications, explicitly, r...
# 12170    [theoretical, framework, normalization, normal...
# 2741     [monotonic, improvement, desirable, properties...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8856 words.
# Out of those 4574 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="22a2e1a4-4376-46e8-a76b-4e486d2c7464" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22a2e1a4-4376-46e8-a76b-4e486d2c7464")) {                    Plotly.newPlot(                        "22a2e1a4-4376-46e8-a76b-4e486d2c7464",                        [{"x":["strengths","introduce","benchmark","progressively","informative","recognition","capability","attracted","mechanism","performance","sequences","dependencies","sequential","selectively","attention","recurrent","promising","effectively","irrelevant","challenging","certainly","mahalanobis","autoencoder","regardless","indicating","semantically","newsgroup","parameter","symmetric","variational","euclidean","represented","correctly","experiments","coherence","distribution","continuous","documents","embedding","additional","geometric","accomplished","variables","generating","algorithm","allocation","efficient","unprecedentedly","dirichlet","carefully","applications","algorithms","demonstrate","complexity","developed","developing","conditions","consistently","metropolis","empirical","comparable","efficiency","throughput","automatically","parameters","regularization","employing","convolutional","maximizing","formulated","convergence","prediction","optimized","classifier","candidates","efficiently","estimated","representations","accelerates","heterogeneous","competitive","framework","validation","performing","illustrates","facilitate","metaconflict","plausibility","established","specifying","criterion","uncertain","subsequent","dempsters","affiliation","plausible","referring","representing","credibility","indication","specified","partitioning","propositions","partition","proposition","constructed","methodology","reasoning","specification","inference","restrictions","improvements","techniques","different","architecture","propagate","boundaries","generated","important","probabilistic","information","experimentally","quantitative","respectively","qualitative","graphical","alleviate","pixelwise","segmentation","correction","intermediate","structure","optimization","approaches","erroneous","representation","combining","projected","vocabulary","bidirectional","outperforms","converted","preceding","adaptively","character","dimensional","introduced","practical","disjunction","semantics","implemented","knowledge","relevance","unrestricted","elementary","transformation","available","straightforward","conjunction","resulting","preliminary","translation","challenge","disjunctive","programming","formalisms","exponential","expressions","polynomial","arbitrarily","transformed","according","understood","literature","relationship","probabilities","condition","schneider","characterize","distributions","uncertainty","consistency","probability","reasonable","conditioning","inconsistency","theoretic","decisions","described","emphasize","calibration","anomalies","questions","significantly","utilizing","experimental","childrens","predictions","comprehension","representative"],"y":[20,327,185,16,34,404,58,32,110,853,97,50,83,7,180,132,112,104,17,275,3,3,27,11,12,34,0,134,20,46,29,96,29,598,19,212,107,67,103,131,76,8,129,98,818,32,391,1,23,36,412,574,547,243,236,62,143,32,3,149,106,153,13,190,226,70,38,396,17,44,107,259,58,171,27,174,64,226,4,42,133,565,49,77,12,48,2,6,52,12,51,27,31,6,1,20,8,83,3,6,32,14,4,24,5,65,67,126,19,216,15,113,379,751,233,9,31,176,358,149,681,49,85,83,75,53,31,2,183,20,33,339,315,458,9,375,115,16,28,22,263,20,5,18,47,179,125,138,6,98,107,378,37,3,13,60,324,18,26,155,47,135,141,10,131,12,61,38,76,16,21,108,25,133,78,63,58,2,38,107,77,58,168,38,14,9,40,65,80,12,22,9,64,270,33,366,5,89,14,34],"type":"bar"},{"x":["strengths","introduce","benchmark","progressively","informative","recognition","cap ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4574,), (4574, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8333333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Cleaning</span> <span style=''>Schedule</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>of</span> <span style=''>Heat</span> <span style=''>Exchanger</span> <span style=''>Networks</span> <span style=''>Using</span> <span style=''>Particle</span> <span style=''>Swarm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Oil</span> <span style=''>refinery</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>industries</span> <span style=''>that</span> <span style=''>require</span> <span style=''>huge</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.5151515151515151);'>consumption</span> <span style=''>The</span> <span style=''>today</span> <span style='background-color:rgba(0, 255, 0, 0.5774647887323943);'>technology</span> <span style=''>advance</span> <span style=''>requires</span> <span style=''>energy</span> <span style=''>saving</span> <span style=''>Heat</span> <span style='background-color:rgba(0, 255, 0, 0.3157894736842105);'>integration</span> <span style=''>is</span> <span style=''>a</span> <span style=''>method</span> <span style=''>used</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>energy</span> <span style=''>comsumption</span> <span style=''>though</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>Heat</span> <span style=''>Exchanger</span> <span style=''>Network</span> <span style=''>(HEN)</span> <span style=''>CPT</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>types</span> <span style=''>of</span> <span style=''>Heat</span> <span style=''>Exchanger</span> <span style=''>Network</span> <span style=''>(HEN)</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style=''>heat</span> <span style=''>in</span> <span style=''>the</span> <span style=''>flow</span> <span style=''>of</span> <span style=''>product</span> <span style=''>or</span> <span style=''>waste</span> <span style=''>HEN</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>comprises</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>heat</span> <span style=''>exchangers</span> <span style=''>(HEs)</span> <span style=''>that</span> <span style=''>are</span> <span style=''>serially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connected</span> <span style=''>However</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>fouling</span> <span style=''>in</span> <span style=''>the</span> <span style=''>heat</span> <span style=''>exchanger</span> <span style=''>has</span> <span style=''>caused</span> <span style=''>the</span> <span style=''>decline</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>both</span> <span style=''>heat</span> <span style=''>exchangers</span> <span style=''>and</span> <span style=''>all</span> <span style=''>heat</span> <span style=''>exchanger</span> <span style=''>networks</span> <span style=''>Fouling</span> <span style=''>can</span> <span style=''>not</span> <span style=''>be</span> <span style=''>avoided</span> <span style=''>However</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>mitigated</span> <span style=''>In</span> <span style=''>industry</span> <span style=''>periodic</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>I</span> <span style=''>know</span> <span style=''>it</span> <span style=''>when</span> <span style=''>I</span> <span style=''>see</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Visualization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Intuitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretability</span> <br/><br/><span style=''>Most</span> <span style=''>research</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>systems</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>of</span> <span style=''>a</span> <span style=''>more</span> <span style=''>rigorous</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>I</span> <span style=''>suggest</span> <span style=''>that</span> <span style=''>a</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deficiencies</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>is</span> <span style=''>needed</span> <span style=''>as</span> <span style=''>well</span> <span style=''>I</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualization</span> <span style=''>enables</span> <span style=''>but</span> <span style=''>also</span> <span style=''>impedes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>as</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>presupposes</span> <span style=''>two</span> <span style=''>levels</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technical</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>I</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>positive</span> <span style=''>concepts</span> <span style=''>to</span> <span style=''>emulate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>human</span> <span style=''>bias</span> <span style=''>into</span> <span style=''>the</span> <span style=''>model</span> <span style=''>As</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consequence</span> <span style=''>I</span> <span style=''>suggest</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Gradient</span> <span style=''>descent</span> <span style=''>GAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>is</span> <span style=''>locally</span> <span style=''>stable</span> <br/><br/><span style=''>Despite</span> <span style=''>the</span> <span style=''>growing</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>prominence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>networks</span> <span style=''>(GANs)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>in</span> <span style=''>GANs</span> <span style=''>is</span> <span style=''>still</span> <span style=''>a</span> <span style=''>poorly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style=''>topic</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>form</span> <span style=''>of</span> <span style=''>GAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>natural</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>take</span> <span style=''>small</span> <span style=''>gradient</span> <span style=''>steps</span> <span style=''>in</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3181818181818181);'>generator</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminator</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>even</span> <span style=''>though</span> <span style=''>GAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>does</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>concave</span> <span style=''>game</span> <span style=''>(even</span> <span style=''>for</span> <span style=''>simple</span> <span style=''>parameterizations)</span> <span style=''>under</span> <span style=''>proper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384616);'>equilibrium</span> <span style=''>points</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>are</span> <span style=''>still</span> <span style=''>emphlocally</span> <span style='background-color:rgba(255, 0, 0, 0.4461538461538462);'>asymptotically</span> <span style=''>stable</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3138686131386861);'>traditional</span> <span style=''>GAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>recently</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.5172413793103449);'>Wasserstein</span> <span style=''>GAN</span> <span style=''>can</span> <span style=''>have</span> <span style=''>non</span> <span style='bac ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>Kernel</span> <span style=''>Machines</span> <span style=''>with</span> <span style=''>Implicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Randomization</span> <br/><br/><span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>fully</span> <span style=''>utilize</span> <span style=''>big</span> <span style=''>data</span> <span style=''>it</span> <span style=''>is</span> <span style=''>often</span> <span style=''>required</span> <span style=''>to</span> <span style=''>use</span> <span style=''>big</span> <span style=''>models</span> <span style=''>Such</span> <span style=''>models</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>grow</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>and</span> <span style=''>do</span> <span style=''>not</span> <span style=''>make</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>upfront</span> <span style=''>on</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>Kernel</span> <span style=''>methods</span> <span style=''>fit</span> <span style=''>this</span> <span style=''>need</span> <span style=''>well</span> <span style=''>as</span> <span style=''>they</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constitute</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>versatile</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>problems</span> <span style=''>However</span> <span style=''>their</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>costs</span> <span style=''>(in</span> <span style=''>storage</span> <span style=''>and</span> <span style=''>time)</span> <span style=''>pose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>barrier</span> <span style=''>to</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>widespread</span> <span style=''>adoption</span> <span style=''>in</span> <span style=''>big</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(25 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.0836624775583483)
# 	evaluation (0.09694793536804308)
# 	knowledge (0.13572710951526032)
# 	segmentation (0.06570915619389588)
# 	information (0.244524236983842)
# 	representation (0.13464991023339318)
# 	detection (0.12351885098743268)
# 	different (0.2696588868940754)
# 	convolutional (0.1421903052064632)
# 	recognition (0.1450628366247756)
#
# Some Statistics words are:
# 	variables (0.1359801488833747)
# 	algorithm (0.38461538461538464)
# 	stochastic (0.1325062034739454)
# 	estimation (0.16923076923076924)
# 	distribution (0.1761786600496278)
# 	statistical (0.15781637717121588)
# 	theoretical (0.15186104218362284)
# 	inference (0.1826302729528536)
# 	dimensional (0.18858560794044665)
# 	regression (0.18957816377171216)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="26401a7c-a595-4a31-beee-4eab38fc80e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26401a7c-a595-4a31-beee-4eab38fc80e2")) {                    Plotly.newPlot(                        "26401a7c-a595-4a31-beee-4eab38fc80e2",                        [{"x":["strengths","introduce","benchmark","progressively","informative","recognition","capability","attracted","mechanism","performance","sequences","dependencies","sequential","selectively","attention","recurrent","promising","effectively","irrelevant","challenging","certainly","mahalanobis","autoencoder","regardless","indicating","semantically","newsgroup","parameter","symmetric","variational","euclidean","represented","correctly","experiments","coherence","distribution","continuous","documents","embedding","additional","geometric","accomplished","variables","generating","algorithm","allocation","efficient","unprecedentedly","dirichlet","carefully","applications","algorithms","demonstrate","complexity","developed","developing","conditions","consistently","metropolis","empirical","comparable","efficiency","throughput","automatically","parameters","regularization","employing","convolutional","maximizing","formulated","convergence","prediction","optimized","classifier","candidates","efficiently","estimated","representations","accelerates","heterogeneous","competitive","framework","validation","performing","illustrates","facilitate","metaconflict","plausibility","established","specifying","criterion","uncertain","subsequent","dempsters","affiliation","plausible","referring","representing","credibility","indication","specified","partitioning","propositions","partition","proposition","constructed","methodology","reasoning","specification","inference","restrictions","improvements","techniques","different","architecture","propagate","boundaries","generated","important","probabilistic","information","experimentally","quantitative","respectively","qualitative","graphical","alleviate","pixelwise","segmentation","correction","intermediate","structure","optimization","approaches","erroneous","representation","combining","projected","vocabulary","bidirectional","outperforms","converted","preceding","adaptively","character","dimensional","introduced","practical","disjunction","semantics","implemented","knowledge","relevance","unrestricted","elementary","transformation","available","straightforward","conjunction","resulting","preliminary","translation","challenge","disjunctive","programming","formalisms","exponential","expressions","polynomial","arbitrarily","transformed","according","understood","literature","relationship","probabilities","condition","schneider","characterize","distributions","uncertainty","consistency","probability","reasonable","conditioning","inconsistency","theoretic","decisions","described","emphasize","calibration","anomalies","questions","significantly","utilizing","experimental","childrens","predictions","comprehension","representative","integrate","preserved","effective","variations","surprisingly","surrounding","threshold","convolution","consuming","furthermore","favorably","similarities","structural","contextual","successfully","discriminative","normalized","auxiliary","lightweight","intensity","remaining","shrinkage","appearance","empirically","synthesis","omnipresent","generative","diversity","intractable","simulators","regularised","alleviates","optimisation","estimator","evaluation","scientific","implicitly","engineering","adversarial","approximations","estimators","generation","approximating","estimates","demonstrated","objective","approximate","inaccurate","proposing","nonconvex","understand","evolutionary","complicated","particularly","conducting","answering","outperf ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	newsgroup
# 	stabilizes
# 	spectroscopy
# 	parsimony
# 	frequentist
# 	underpowered
# 	submodels
# 	exponents
# 	regulating
# 	kontorovich
# 	missforest
# 	profitable
# 	symplectic
# 	integrator
# 	linearities
# 	incidentally
# 	penalties
# 	electrocardiogram
# 	advantageously
# 	irradiance
# Some words which never appear in Statistics papers:
# 	metaconflict
# 	dempsters
# 	credibility
# 	propositions
# 	disjunction
# 	formalisms
# 	schneider
# 	appearance
# 	topographic
# 	alternately
# 	displayed
# 	thereafter
# 	pictorial
# 	reproduction
# 	earthquake
# 	strengthen
# 	disjunctions
# 	efficiencies
# 	lexicographic
# 	diversification

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.08413520848754e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333
